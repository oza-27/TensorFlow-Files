# %%
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series(["BMW", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series is 1-dimensional

# %%
colours = pd.Series(["Blue", "Yellow", "Green", "White"])

# %%
colours
# Out:
# 0      Blue
# 1    Yellow
# 2     Green
# 3     White
# dtype: object

# %%
# DataFrame = 2-dimensional
car_data = pd.DataFrame({"Car make": series, "Colours": colours})
car_data
# Out:
#   Car make Colours
# 0      BMW    Blue
# 1   Toyota  Yellow
# 2    Honda   Green
# 3      NaN   White

# %%
#import data
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make  Colour  Odometer  Doors    Price
# 0  Toyota   White     15009      4   $4,000
# 1   Honda     Red     34555      4   $3,400
# 2  Toyota    Blue     43222      4  $32,000
# 3     BMW   Green      1234      4  $22,000
# 4  Nissan  Violet     54444      3  $12,000
# 5  Toyota   White     66578      4  $12,333
# 6   Honda    Blue     78966      3  $12,000
# 7   Honda    Blue     56788      4  $34,000
# 8  Toyota   Green     45788      3  $65,000
# 9  Nissan     Red     89776      3  $23,000

# %%
# Exporting our DataFrame
car_sales.to_csv("exported-car-sales.csv", index=False)

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#      Make  Colour  Odometer  Doors    Price
# 0  Toyota   White     15009      4   $4,000
# 1   Honda     Red     34555      4   $3,400
# 2  Toyota    Blue     43222      4  $32,000
# 3     BMW   Green      1234      4  $22,000
# 4  Nissan  Violet     54444      3  $12,000
# 5  Toyota   White     66578      4  $12,333
# 6   Honda    Blue     78966      3  $12,000
# 7   Honda    Blue     56788      4  $34,000
# 8  Toyota   Green     45788      3  $65,000
# 9  Nissan     Red     89776      3  $23,000

# %% [markdown]
# # Describe Data

# %%
# Attributes
car_sales.dtypes

# Function
# car_sales.to_csv()
# Out:
# Make        object
# Colour      object
# Odometer     int64
# Doors        int64
# Price       object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make  Colour  Odometer  Doors    Price
# 0  Toyota   White     15009      4   $4,000
# 1   Honda     Red     34555      4   $3,400
# 2  Toyota    Blue     43222      4  $32,000
# 3     BMW   Green      1234      4  $22,000
# 4  Nissan  Violet     54444      3  $12,000
# 5  Toyota   White     66578      4  $12,333
# 6   Honda    Blue     78966      3  $12,000
# 7   Honda    Blue     56788      4  $34,000
# 8  Toyota   Green     45788      3  $65,000
# 9  Nissan     Red     89776      3  $23,000

# %%
car_sales.describe()
# Out:
#            Odometer      Doors
# count     10.000000  10.000000
# mean   48636.000000   3.600000
# std    27178.287138   0.516398
# min     1234.000000   3.000000
# 25%    36721.750000   3.000000
# 50%    50116.000000   4.000000
# 75%    64130.500000   4.000000
# max    89776.000000   4.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Make      10 non-null     object
#  1   Colour    10 non-null     object
#  2   Odometer  10 non-null     int64
#  3   Doors     10 non-null     int64
#  4   Price     10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer    48636.0
# Doors           3.6
# dtype: float64

# %%
car_prices = pd.Series([3000,4000,5000,2000])
car_prices.mean()
# Out:
# 3500.0

# %%
car_sales.sum()
# Out:
# Make        ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour           WhiteRedBlueGreenVioletWhiteBlueBlueGreenRed
# Odometer                                               486360
# Doors                                                      36
# Price       $4,000$3,400$32,000$22,000$12,000$12,333$12,00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 36

# %%
car_sales["Price"].sum()
# Out:
# '$4,000$3,400$32,000$22,000$12,000$12,333$12,000$34,000$65,000$23,000'

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
#      Make  Colour  Odometer  Doors    Price
# 0  Toyota   White     15009      4   $4,000
# 1   Honda     Red     34555      4   $3,400
# 2  Toyota    Blue     43222      4  $32,000
# 3     BMW   Green      1234      4  $22,000
# 4  Nissan  Violet     54444      3  $12,000
# 5  Toyota   White     66578      4  $12,333
# 6   Honda    Blue     78966      3  $12,000
# 7   Honda    Blue     56788      4  $34,000
# 8  Toyota   Green     45788      3  $65,000
# 9  Nissan     Red     89776      3  $23,000

# %% [markdown]
# ## Viewing and Selecting Data

# %%
car_sales.head()
# Out:
#      Make  Colour  Odometer  Doors    Price
# 0  Toyota   White     15009      4   $4,000
# 1   Honda     Red     34555      4   $3,400
# 2  Toyota    Blue     43222      4  $32,000
# 3     BMW   Green      1234      4  $22,000
# 4  Nissan  Violet     54444      3  $12,000

# %%
cr_sales.tails()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-8cc4b03f8d55> in <module>
# ----> 1 cr_sales.tails()
#
# NameError: name 'cr_sales' is not defined

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer  Doors    Price
# 5  Toyota  White     66578      4  $12,333
# 6   Honda   Blue     78966      3  $12,000
# 7   Honda   Blue     56788      4  $34,000
# 8  Toyota  Green     45788      3  $65,000
# 9  Nissan    Red     89776      3  $23,000

# %%
# . loc and .iloc
animals = pd.Series(["cat", "Dog", "Cow", "Bird", "Panda", "Snake"], index=[0, 3, 9, 8, 3, 8])

# %%
animals
# Out:
# 0      cat
# 3      Dog
# 9      Cow
# 8     Bird
# 3    Panda
# 8    Snake
# dtype: object

# %%
animals.loc[8]
# Out:
# 8     Bird
# 8    Snake
# dtype: object

# %%
car_sales
# Out:
#      Make  Colour  Odometer  Doors    Price
# 0  Toyota   White     15009      4   $4,000
# 1   Honda     Red     34555      4   $3,400
# 2  Toyota    Blue     43222      4  $32,000
# 3     BMW   Green      1234      4  $22,000
# 4  Nissan  Violet     54444      3  $12,000
# 5  Toyota   White     66578      4  $12,333
# 6   Honda    Blue     78966      3  $12,000
# 7   Honda    Blue     56788      4  $34,000
# 8  Toyota   Green     45788      3  $65,000
# 9  Nissan     Red     89776      3  $23,000

# %%
car_sales.loc[3]
# Out:
# Make            BMW
# Colour        Green
# Odometer       1234
# Doors             4
# Price       $22,000
# Name: 3, dtype: object

# %%
# .iloc
animals.iloc[3]
# Out:
# 'Bird'

# %%
car_sales.iloc[3]
# Out:
# Make            BMW
# Colour        Green
# Odometer       1234
# Doors             4
# Price       $22,000
# Name: 3, dtype: object

# %%
 animals.iloc[:3]
# Out:
# 0    cat
# 3    Dog
# 9    Cow
# dtype: object

# %%
animals
# Out:
# 0      cat
# 3      Dog
# 9      Cow
# 8     Bird
# 3    Panda
# 8    Snake
# dtype: object

# %%
car_sales
# Out:
#      Make  Colour  Odometer  Doors    Price
# 0  Toyota   White     15009      4   $4,000
# 1   Honda     Red     34555      4   $3,400
# 2  Toyota    Blue     43222      4  $32,000
# 3     BMW   Green      1234      4  $22,000
# 4  Nissan  Violet     54444      3  $12,000
# 5  Toyota   White     66578      4  $12,333
# 6   Honda    Blue     78966      3  $12,000
# 7   Honda    Blue     56788      4  $34,000
# 8  Toyota   Green     45788      3  $65,000
# 9  Nissan     Red     89776      3  $23,000

# %%
car_sales.iloc[:5]
# Out:
#      Make  Colour  Odometer  Doors    Price
# 0  Toyota   White     15009      4   $4,000
# 1   Honda     Red     34555      4   $3,400
# 2  Toyota    Blue     43222      4  $32,000
# 3     BMW   Green      1234      4  $22,000
# 4  Nissan  Violet     54444      3  $12,000

# %%
car_sales.head(4)
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White     15009      4   $4,000
# 1   Honda    Red     34555      4   $3,400
# 2  Toyota   Blue     43222      4  $32,000
# 3     BMW  Green      1234      4  $22,000

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0     White
# 1       Red
# 2      Blue
# 3     Green
# 4    Violet
# 5     White
# 6      Blue
# 7      Blue
# 8     Green
# 9       Red
# Name: Colour, dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Odometer"]
# Out:
# 0    15009
# 1    34555
# 2    43222
# 3     1234
# 4    54444
# 5    66578
# 6    78966
# 7    56788
# 8    45788
# 9    89776
# Name: Odometer, dtype: int64

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White     15009      4   $4,000
# 2  Toyota   Blue     43222      4  $32,000
# 5  Toyota  White     66578      4  $12,333
# 8  Toyota  Green     45788      3  $65,000

# %%
car_sales[car_sales["Odometer"] > 10000]
# Out:
#      Make  Colour  Odometer  Doors    Price
# 0  Toyota   White     15009      4   $4,000
# 1   Honda     Red     34555      4   $3,400
# 2  Toyota    Blue     43222      4  $32,000
# 4  Nissan  Violet     54444      3  $12,000
# 5  Toyota   White     66578      4  $12,333
# 6   Honda    Blue     78966      3  $12,000
# 7   Honda    Blue     56788      4  $34,000
# 8  Toyota   Green     45788      3  $65,000
# 9  Nissan     Red     89776      3  $23,000

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4
# Make
# BMW     0  1
# Honda   1  2
# Nissan  2  0
# Toyota  1  3

# %%
car_sales
# Out:
#      Make  Colour  Odometer  Doors    Price
# 0  Toyota   White     15009      4   $4,000
# 1   Honda     Red     34555      4   $3,400
# 2  Toyota    Blue     43222      4  $32,000
# 3     BMW   Green      1234      4  $22,000
# 4  Nissan  Violet     54444      3  $12,000
# 5  Toyota   White     66578      4  $12,333
# 6   Honda    Blue     78966      3  $12,000
# 7   Honda    Blue     56788      4  $34,000
# 8  Toyota   Green     45788      3  $65,000
# 9  Nissan     Red     89776      3  $23,000

# %%
# Groupby
car_sales.groupby(["Doors"]).mean()
# Out:
#        Odometer
# Doors
# 3       67243.5
# 4       36231.0

# %%
car_sales["Odometer"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Odometer"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-83bf2f29b5a6> in <module>
# ----> 1 car_sales["Price"].plot()
#
# ~\Desktop\sample_project_1\env\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~\Desktop\sample_project_1\env\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\Desktop\sample_project_1\env\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
# ...

# %%
car_sales

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)

# %%
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-83bf2f29b5a6> in <module>
# ----> 1 car_sales["Price"].plot()
#
# ~\Desktop\sample_project_1\env\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~\Desktop\sample_project_1\env\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\Desktop\sample_project_1\env\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
# ...

# %%
car_sales
# Out:
#      Make  Colour  Odometer  Doors    Price
# 0  Toyota   White     15009      4   $4,000
# 1   Honda     Red     34555      4   $3,400
# 2  Toyota    Blue     43222      4  $32,000
# 3     BMW   Green      1234      4  $22,000
# 4  Nissan  Violet     54444      3  $12,000
# 5  Toyota   White     66578      4  $12,333
# 6   Honda    Blue     78966      3  $12,000
# 7   Honda    Blue     56788      4  $34,000
# 8  Toyota   Green     45788      3  $65,000
# 9  Nissan     Red     89776      3  $23,000

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make  Colour  Odometer  Doors    Price
# 0  toyota   White     15009      4   $4,000
# 1   honda     Red     34555      4   $3,400
# 2  toyota    Blue     43222      4  $32,000
# 3     bmw   Green      1234      4  $22,000
# 4  nissan  Violet     54444      3  $12,000
# 5  toyota   White     66578      4  $12,333
# 6   honda    Blue     78966      3  $12,000
# 7   honda    Blue     56788      4  $34,000
# 8  toyota   Green     45788      3  $65,000
# 9  nissan     Red     89776      3  $23,000

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
 car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour Odometer  Doors    Price
# 0  Toyota  White     None    4.0   $4,000
# 1   Honda    Red     None    4.0   $5,000
# 2  Toyota   Blue     None    3.0   $7,000
# 3     BMW  Black     None    5.0  $22,000
# 4  Nissan  White     None    4.0   $3,500
# 5  Toyota  Green     None    4.0   $4,500
# 6   Honda    NaN     None    4.0   $7,500
# 7   Honda   Blue     None    4.0      NaN
# 8  Toyota  White     None    NaN      NaN
# 9     NaN  White     None    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
# Empty DataFrame
# Columns: [Make, Colour, Odometer, Doors, Price]
# Index: []

# %%
car_sales_missing
# Out:
#      Make Colour Odometer  Doors    Price
# 0  Toyota  White     None    4.0   $4,000
# 1   Honda    Red     None    4.0   $5,000
# 2  Toyota   Blue     None    3.0   $7,000
# 3     BMW  Black     None    5.0  $22,000
# 4  Nissan  White     None    4.0   $3,500
# 5  Toyota  Green     None    4.0   $4,500
# 6   Honda    NaN     None    4.0   $7,500
# 7   Honda   Blue     None    4.0      NaN
# 8  Toyota  White     None    NaN      NaN
# 9     NaN  White     None    4.0   $9,700

# %%
# Column from series
seats_column = pd.Series([5, 5, 5, 5, 5])

# New column called seats
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make  Colour  Odometer  Doors    Price  Seats
# 0  toyota   White     15009      4   $4,000    5.0
# 1   honda     Red     34555      4   $3,400    5.0
# 2  toyota    Blue     43222      4  $32,000    5.0
# 3     bmw   Green      1234      4  $22,000    5.0
# 4  nissan  Violet     54444      3  $12,000    5.0
# 5  toyota   White     66578      4  $12,333    NaN
# 6   honda    Blue     78966      3  $12,000    NaN
# 7   honda    Blue     56788      4  $34,000    NaN
# 8  toyota   Green     45788      3  $65,000    NaN
# 9  nissan     Red     89776      3  $23,000    NaN

# %%
car_sales["Seats"].fillna(5, inplace=True)

# %%
car_sales
# Out:
#      Make  Colour  Odometer  Doors    Price  Seats
# 0  toyota   White     15009      4   $4,000    5.0
# 1   honda     Red     34555      4   $3,400    5.0
# 2  toyota    Blue     43222      4  $32,000    5.0
# 3     bmw   Green      1234      4  $22,000    5.0
# 4  nissan  Violet     54444      3  $12,000    5.0
# 5  toyota   White     66578      4  $12,333    5.0
# 6   honda    Blue     78966      3  $12,000    5.0
# 7   honda    Blue     56788      4  $34,000    5.0
# 8  toyota   Green     45788      3  $65,000    5.0
# 9  nissan     Red     89776      3  $23,000    5.0

# %%
# Column from python list
fuel_economy = [7.5, 9.2, 5.0, 9.6, 5.4, 4.9, 7.3, 3.8, 6.7, 2.4]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#      Make  Colour  Odometer  Doors    Price  Seats  Fuel per 100KM
# 0  toyota   White     15009      4   $4,000    5.0             7.5
# 1   honda     Red     34555      4   $3,400    5.0             9.2
# 2  toyota    Blue     43222      4  $32,000    5.0             5.0
# 3     bmw   Green      1234      4  $22,000    5.0             9.6
# 4  nissan  Violet     54444      3  $12,000    5.0             5.4
# 5  toyota   White     66578      4  $12,333    5.0             4.9
# 6   honda    Blue     78966      3  $12,000    5.0             7.3
# 7   honda    Blue     56788      4  $34,000    5.0             3.8
# 8  toyota   Green     45788      3  $65,000    5.0             6.7
# 9  nissan     Red     89776      3  $23,000    5.0             2.4

# %%
car_sales["Total fuel Used (L)"] = car_sales["Odometer"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make  Colour  Odometer  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota   White     15009      4   $4,000    5.0             7.5
# 1   honda     Red     34555      4   $3,400    5.0             9.2
# 2  toyota    Blue     43222      4  $32,000    5.0             5.0
# 3     bmw   Green      1234      4  $22,000    5.0             9.6
# 4  nissan  Violet     54444      3  $12,000    5.0             5.4
# 5  toyota   White     66578      4  $12,333    5.0             4.9
# 6   honda    Blue     78966      3  $12,000    5.0             7.3
# 7   honda    Blue     56788      4  $34,000    5.0             3.8
# 8  toyota   Green     45788      3  $65,000    5.0             6.7
# 9  nissan     Red     89776      3  $23,000    5.0             2.4
#
#    Total fuel Used (L)
# 0             1125.675
# 1             3179.060
# 2             2161.100
# 3              118.464
# 4             2939.976
# 5             3262.322
# 6             5764.518
# 7             2157.944
# ...

# %%
# Create a column from single value
car_sales["Number of Wheel"] = 4
car_sales
# Out:
#      Make  Colour  Odometer  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota   White     15009      4   $4,000    5.0             7.5
# 1   honda     Red     34555      4   $3,400    5.0             9.2
# 2  toyota    Blue     43222      4  $32,000    5.0             5.0
# 3     bmw   Green      1234      4  $22,000    5.0             9.6
# 4  nissan  Violet     54444      3  $12,000    5.0             5.4
# 5  toyota   White     66578      4  $12,333    5.0             4.9
# 6   honda    Blue     78966      3  $12,000    5.0             7.3
# 7   honda    Blue     56788      4  $34,000    5.0             3.8
# 8  toyota   Green     45788      3  $65,000    5.0             6.7
# 9  nissan     Red     89776      3  $23,000    5.0             2.4
#
#    Total fuel Used (L)  Number of Wheel
# 0             1125.675                4
# 1             3179.060                4
# 2             2161.100                4
# 3              118.464                4
# ...

# %%
car_sales["Passed road safety"] = True
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer                 int64
# Doors                    int64
# Price                   object
# Seats                  float64
# Fuel per 100KM         float64
# Total fuel Used (L)    float64
# Number of Wheel          int64
# Passed road safety        bool
# dtype: object

# %%
car_sales
# Out:
#      Make  Colour  Odometer  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota   White     15009      4   $4,000    5.0             7.5
# 1   honda     Red     34555      4   $3,400    5.0             9.2
# 2  toyota    Blue     43222      4  $32,000    5.0             5.0
# 3     bmw   Green      1234      4  $22,000    5.0             9.6
# 4  nissan  Violet     54444      3  $12,000    5.0             5.4
# 5  toyota   White     66578      4  $12,333    5.0             4.9
# 6   honda    Blue     78966      3  $12,000    5.0             7.3
# 7   honda    Blue     56788      4  $34,000    5.0             3.8
# 8  toyota   Green     45788      3  $65,000    5.0             6.7
# 9  nissan     Red     89776      3  $23,000    5.0             2.4
#
#    Total fuel Used (L)  Number of Wheel  Passed road safety
# 0             1125.675                4                True
# 1             3179.060                4                True
# ...

# %%
car_sales.drop("Total fuel Used", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-29b3230403b1> in <module>
# ----> 1 car_sales.drop("Total fuel Used", axis=1)
#
# ~\Desktop\sample_project_1\env\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4303                 weight  1.0     0.8
#    4304         """
# -> 4305         return super().drop(
#    4306             labels=labels,
#    4307             axis=axis,
#
# ~\Desktop\sample_project_1\env\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4150         for axis, labels in axes.items():
#    4151             if labels is not None:
# -> 4152                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4153
#    4154         if inplace:
#
# ...

# %%
car_sales_shuffled = car_sales.sample(frac=(1))
car_sales_shuffled
# Out:
#      Make  Colour  Odometer  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota   White     15009      4   $4,000    5.0             7.5
# 1   honda     Red     34555      4   $3,400    5.0             9.2
# 7   honda    Blue     56788      4  $34,000    5.0             3.8
# 9  nissan     Red     89776      3  $23,000    5.0             2.4
# 3     bmw   Green      1234      4  $22,000    5.0             9.6
# 8  toyota   Green     45788      3  $65,000    5.0             6.7
# 4  nissan  Violet     54444      3  $12,000    5.0             5.4
# 5  toyota   White     66578      4  $12,333    5.0             4.9
# 6   honda    Blue     78966      3  $12,000    5.0             7.3
# 2  toyota    Blue     43222      4  $32,000    5.0             5.0
#
#    Total fuel Used (L)  Number of Wheel  Passed road safety
# 0             1125.675                4                True
# 1             3179.060                4                True
# ...

# %%
car_sales_shuffled.sample(frac=0.09)
# Out:
#     Make Colour  Odometer  Doors    Price  Seats  Fuel per 100KM  \
# 6  honda   Blue     78966      3  $12,000    5.0             7.3
#
#    Total fuel Used (L)  Number of Wheel  Passed road safety
# 6             5764.518                4                True

# %%
# Only select 20% of data
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make  Colour  Odometer  Doors    Price  Seats  Fuel per 100KM  \
# 4  nissan  Violet     54444      3  $12,000    5.0             5.4
# 8  toyota   Green     45788      3  $65,000    5.0             6.7
#
#    Total fuel Used (L)  Number of Wheel  Passed road safety
# 4             2939.976                4                True
# 8             3067.796                4                True

# %%
car_sales_shuffled
# Out:
#      Make  Colour  Odometer  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota   White     15009      4   $4,000    5.0             7.5
# 1   honda     Red     34555      4   $3,400    5.0             9.2
# 7   honda    Blue     56788      4  $34,000    5.0             3.8
# 9  nissan     Red     89776      3  $23,000    5.0             2.4
# 3     bmw   Green      1234      4  $22,000    5.0             9.6
# 8  toyota   Green     45788      3  $65,000    5.0             6.7
# 4  nissan  Violet     54444      3  $12,000    5.0             5.4
# 5  toyota   White     66578      4  $12,333    5.0             4.9
# 6   honda    Blue     78966      3  $12,000    5.0             7.3
# 2  toyota    Blue     43222      4  $32,000    5.0             5.0
#
#    Total fuel Used (L)  Number of Wheel  Passed road safety
# 0             1125.675                4                True
# 1             3179.060                4                True
# ...

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffled
# Out:
#    level_0  index    Make  Colour  Odometer  Doors    Price  Seats  \
# 0        0      0  toyota   White     15009      4   $4,000    5.0
# 1        1      1   honda     Red     34555      4   $3,400    5.0
# 2        2      7   honda    Blue     56788      4  $34,000    5.0
# 3        3      9  nissan     Red     89776      3  $23,000    5.0
# 4        4      3     bmw   Green      1234      4  $22,000    5.0
# 5        5      8  toyota   Green     45788      3  $65,000    5.0
# 6        6      4  nissan  Violet     54444      3  $12,000    5.0
# 7        7      5  toyota   White     66578      4  $12,333    5.0
# 8        8      6   honda    Blue     78966      3  $12,000    5.0
# 9        9      2  toyota    Blue     43222      4  $32,000    5.0
#
#    Fuel per 100KM  Total fuel Used (L)  Number of Wheel  Passed road safety
# 0             7.5             1125.675                4                True
# 1             9.2             3179.060                4                True
# ...

# %%
car_sales["Odometer"] = car_sales["Odometer"].apply(lambda x: x / 1.6)
car_sales
# Out:
#      Make  Colour   Odometer  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota   White   9380.625      4   $4,000    5.0             7.5
# 1   honda     Red  21596.875      4   $3,400    5.0             9.2
# 2  toyota    Blue  27013.750      4  $32,000    5.0             5.0
# 3     bmw   Green    771.250      4  $22,000    5.0             9.6
# 4  nissan  Violet  34027.500      3  $12,000    5.0             5.4
# 5  toyota   White  41611.250      4  $12,333    5.0             4.9
# 6   honda    Blue  49353.750      3  $12,000    5.0             7.3
# 7   honda    Blue  35492.500      4  $34,000    5.0             3.8
# 8  toyota   Green  28617.500      3  $65,000    5.0             6.7
# 9  nissan     Red  56110.000      3  $23,000    5.0             2.4
#
#    Total fuel Used (L)  Number of Wheel  Passed road safety
# 0             1125.675                4                True
# 1             3179.060                4                True
# ...
