# %% [markdown]
# # Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot();

# %%
plt.plot([1, 2, 3, 4]);

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y);

# %%
# 1st method
fig = plt.figure() # creates a figure
ax = fig.add_subplot() #add some axes
plt.show()

# %%
# 2nd Method
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot(x, y); #add some data
plt.show()

# %%
# 3rd Method
fig, ax = plt.subplots()
ax.plot(x, [50,200,250,350]); # add some data
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ## Matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter notebook
# %matplotlib inline
import matplotlib.pyplot as plt

#1. Prepare Data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

#2. Setup Plot
fig, ax = plt.subplots(figsize = (10,10)) # Width and height

#3. Plot data
ax.plot(x,y);

#4. Customize Plot
ax.set(title="Simple PLot",
      xlabel="X-axis",
      ylabel="Y-axis")

#5. Save & Show (you have the whole Figure)
fig.savefig("images/sample-plot.png")

# %% [markdown]
# ## Making figures with NumPy arrays
#
# We want:
# * Line Plot
# * Scatter plot
# * Bar Plot
# * Histogram
# * Subplots

# %%
import numpy as np

# %%
#Create some Data
x = np.linspace(0, 10, 100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# PLot the data and create a line plot
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
# Use same data to create scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
# Another Scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# Make a plot from dictionary
nut_butter_prices = {"Almond Butter": 10,
                    "Peanur Butter" : 8,
                    "Cashew Butter" : 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), height = nut_butter_prices.values())
ax.set(title="Soumy's Nut Butter Store",
      ylabel="Price($)");

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %%
 # Make some data for histogram
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# # Two options for subplots

# %%
# Subplot option1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                            ncols=2,
                                            figsize=(10,5))
# PLot to each different axis
ax1.plot(x, x/2);
ax1.set(title="Simple-Plot",
       xlabel="X-axis",
       ylabel="Y-axis");
ax2.scatter(np.random.random(10), np.random.random(10));
ax2.set(title="Simple-Scatter",
       xlabel="X-axis",
       ylabel="Y-axis");
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax3.set(title="Simple-Bar",
       xlabel="X-axis");
ax4.hist(np.random.randn(1000));
ax4.set(title="Simple-Histogram",
       xlabel="X-axis",
       ylabel="Y-axis");

# %%
# Subplot option 2
fig, ax = plt.subplots(nrows=2,
                      ncols=2,
                      figsize=(10, 5))
# Plot each to different index
ax[0,0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from Pandas DataFrame

# %%
import pandas as pd

# %%
# Make DataFrame
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make  Colour  Odometer  Doors    Price
# 0  Toyota   White     15009      4   $4,000
# 1   Honda     Red     34555      4   $3,400
# 2  Toyota    Blue     43222      4  $32,000
# 3     BMW   Green      1234      4  $22,000
# 4  Nissan  Violet     54444      3  $12,000
# 5  Toyota   White     66578      4  $12,333
# 6   Honda    Blue     78966      3  $12,000
# 7   Honda    Blue     56788      4  $34,000
# 8  Toyota   Green     45788      3  $65,000
# 9  Nissan     Red     89776      3  $23,000

# %%
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range("1/1/2020", periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
car_sales
# Out:
#      Make  Colour  Odometer  Doors    Price
# 0  Toyota   White     15009      4   $4,000
# 1   Honda     Red     34555      4   $3,400
# 2  Toyota    Blue     43222      4  $32,000
# 3     BMW   Green      1234      4  $22,000
# 4  Nissan  Violet     54444      3  $12,000
# 5  Toyota   White     66578      4  $12,333
# 6   Honda    Blue     78966      3  $12,000
# 7   Honda    Blue     56788      4  $34,000
# 8  Toyota   Green     45788      3  $65,000
# 9  Nissan     Red     89776      3  $23,000

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
car_sales
# Out:
# <ipython-input-23-737e371af5b4>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
#      Make  Colour  Odometer  Doors  Price
# 0  Toyota   White     15009      4   4000
# 1   Honda     Red     34555      4   3400
# 2  Toyota    Blue     43222      4  32000
# 3     BMW   Green      1234      4  22000
# 4  Nissan  Violet     54444      3  12000
# 5  Toyota   White     66578      4  12333
# 6   Honda    Blue     78966      3  12000
# 7   Honda    Blue     56788      4  34000
# 8  Toyota   Green     45788      3  65000
# 9  Nissan     Red     89776      3  23000

# %%
 # Remove last two zeros
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make  Colour  Odometer  Doors Price
# 0  Toyota   White     15009      4    40
# 1   Honda     Red     34555      4    34
# 2  Toyota    Blue     43222      4   320
# 3     BMW   Green      1234      4   220
# 4  Nissan  Violet     54444      3   120
# 5  Toyota   White     66578      4   123
# 6   Honda    Blue     78966      3   120
# 7   Honda    Blue     56788      4   340
# 8  Toyota   Green     45788      3   650
# 9  Nissan     Red     89776      3   230

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2020", periods=len(car_sales))
car_sales
# Out:
#      Make  Colour  Odometer  Doors Price  Sale Date
# 0  Toyota   White     15009      4    40 2020-01-01
# 1   Honda     Red     34555      4    34 2020-01-02
# 2  Toyota    Blue     43222      4   320 2020-01-03
# 3     BMW   Green      1234      4   220 2020-01-04
# 4  Nissan  Violet     54444      3   120 2020-01-05
# 5  Toyota   White     66578      4   123 2020-01-06
# 6   Honda    Blue     78966      3   120 2020-01-07
# 7   Honda    Blue     56788      4   340 2020-01-08
# 8  Toyota   Green     45788      3   650 2020-01-09
# 9  Nissan     Red     89776      3   230 2020-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make  Colour  Odometer  Doors Price  Sale Date  Total Sales
# 0  Toyota   White     15009      4    40 2020-01-01           40
# 1   Honda     Red     34555      4    34 2020-01-02           74
# 2  Toyota    Blue     43222      4   320 2020-01-03          394
# 3     BMW   Green      1234      4   220 2020-01-04          614
# 4  Nissan  Violet     54444      3   120 2020-01-05          734
# 5  Toyota   White     66578      4   123 2020-01-06          857
# 6   Honda    Blue     78966      3   120 2020-01-07          977
# 7   Honda    Blue     56788      4   340 2020-01-08         1317
# 8  Toyota   Green     45788      3   650 2020-01-09         1967
# 9  Nissan     Red     89776      3   230 2020-01-10         2197

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
#Let's plot the total sales
car_sales.plot(x="Sale Date", y="Total Sales");

# %%
#Reassign price column to int
car_sales["Price"] = car_sales["Price"].astype(int);
# Plot scatter plot with price column as numeric
car_sales.plot(x="Odometer", y="Price", kind="scatter");

# %%
# How about a bar graph?
x = np.random.rand(10, 4)

#Turn it into a DataFrame
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.475642  0.860940  0.621074  0.535816
# 1  0.995184  0.483597  0.437284  0.015584
# 2  0.076183  0.921131  0.787090  0.285328
# 3  0.583141  0.506523  0.729803  0.386150
# 4  0.697794  0.069416  0.871273  0.753577
# 5  0.428928  0.664778  0.217759  0.267977
# 6  0.938614  0.770793  0.651667  0.347234
# 7  0.990092  0.011098  0.048366  0.744646
# 8  0.843866  0.306767  0.049589  0.912646
# 9  0.317619  0.355652  0.116758  0.091351

# %%
df.plot.bar();

# %%
car_sales
# Out:
#      Make  Colour  Odometer  Doors  Price  Sale Date  Total Sales
# 0  Toyota   White     15009      4     40 2020-01-01           40
# 1   Honda     Red     34555      4     34 2020-01-02           74
# 2  Toyota    Blue     43222      4    320 2020-01-03          394
# 3     BMW   Green      1234      4    220 2020-01-04          614
# 4  Nissan  Violet     54444      3    120 2020-01-05          734
# 5  Toyota   White     66578      4    123 2020-01-06          857
# 6   Honda    Blue     78966      3    120 2020-01-07          977
# 7   Honda    Blue     56788      4    340 2020-01-08         1317
# 8  Toyota   Green     45788      3    650 2020-01-09         1967
# 9  Nissan     Red     89776      3    230 2020-01-10         2197

# %%
car_sales.plot(x="Make", y="Odometer", kind="bar");

# %%
# How about histograms?
car_sales["Odometer"].plot.hist();

# %%
car_sales
# Out:
#      Make  Colour  Odometer  Doors  Price  Sale Date  Total Sales
# 0  Toyota   White     15009      4     40 2020-01-01           40
# 1   Honda     Red     34555      4     34 2020-01-02           74
# 2  Toyota    Blue     43222      4    320 2020-01-03          394
# 3     BMW   Green      1234      4    220 2020-01-04          614
# 4  Nissan  Violet     54444      3    120 2020-01-05          734
# 5  Toyota   White     66578      4    123 2020-01-06          857
# 6   Honda    Blue     78966      3    120 2020-01-07          977
# 7   Honda    Blue     56788      4    340 2020-01-08         1317
# 8  Toyota   Green     45788      3    650 2020-01-09         1967
# 9  Nissan     Red     89776      3    230 2020-01-10         2197

# %%
car_sales["Odometer"].plot.hist(bins=10);

# %%
# Lets try another DataFrame
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Create a histogram of age
heart_disease["age"].plot.hist(bins=80);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize=(10,30), subplots=True);

# %% [markdown]
# ### Which one should we use? (pyplot vs matplotlib OO method?)
#
# * When plotting something quickly, okay to use the pyplot method
# * When plotting something more advanced, use the OO method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
over_50.plot(kind='scatter',
            x='age',
            y='chol',
            c='target');

# %%
## OO method mixed with pyplot method
fix, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter',
            x='age',
            y='chol',
            c='target',
            ax=ax);

# %%
## OO method from scratch
fig, ax = plt.subplots(figsize=(10,6))

## Plot the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"]);
# Customize the plot
ax.set(title="Heart Disease and Cholestrol Levels",
      xlabel="Age",
      ylabel="Cholestrol");
# Add a legend
ax.legend(*scatter.legend_elements(), title="Target");

# Add a horizontal line
ax.axhline(over_50["chol"].mean(), linestyle='--');

# %%
    over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10));
#Add data to ax0
scatter = ax0.scatter(x=over_50["age"], y=over_50["chol"], c=over_50["target"]);

#Customizw ax0
ax0.set(title="Heart Disease and Cholestrol Levels",
       xlabel="Age",
       ylabel="Cholestrol");

# Add a legend
ax0.legend(*scatter.legend_elements(), title="Target");

#Add a meanline
ax0.axhline(y=over_50["chol"].mean(), linestyle='--');

# Add a data to ax1
scatter = ax1.scatter(x=over_50["age"],
                      y=over_50["thalach"],
                      c=over_50["target"]);

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate",
       xlabel="Age",
       ylabel="Max Heart Rate");

# Add a legend to ax1

ax1.legend(*scatter.legend_elements(), title="Target");

# Add a meanline
ax1.axhline(y=over_50["thalach"].mean(), linestyle='--');

# Add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# %% [markdown]
# ## Customizing Matplotlib plots and getting stylish

# %%
# See the different styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-whitegrid')

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn')

# %%
car_sales["Price"].plot();

# %%
plt.style.use('ggplot')
car_sales["Price"].plot();

# %%
##Create some data
x = np.random.randn(10, 4)
x
# Out:
# array([[ 0.72884251, -0.71564318, -0.90498231, -0.16660102],
#        [-0.78997944,  1.55290393,  0.47615524, -0.49611782],
#        [ 0.21149572,  0.41558204, -0.79674683, -0.12153161],
#        [ 0.64649219, -0.36999762,  0.96046783, -0.10506171],
#        [ 0.36915102, -1.06452444, -0.96879248, -0.08950742],
#        [-0.03735965, -0.29016883, -1.28711906,  0.56448719],
#        [-0.54961433, -0.53061507, -1.16042443,  1.07026287],
#        [ 1.35332815,  0.82348793, -0.07062019,  1.50289988],
#        [-0.87064247, -0.66419819,  1.65173457, -0.81498235],
#        [ 0.88895671, -1.80414927, -1.33803717, -1.22314102]])

# %%
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.728843 -0.715643 -0.904982 -0.166601
# 1 -0.789979  1.552904  0.476155 -0.496118
# 2  0.211496  0.415582 -0.796747 -0.121532
# 3  0.646492 -0.369998  0.960468 -0.105062
# 4  0.369151 -1.064524 -0.968792 -0.089507
# 5 -0.037360 -0.290169 -1.287119  0.564487
# 6 -0.549614 -0.530615 -1.160424  1.070263
# 7  1.353328  0.823488 -0.070620  1.502900
# 8 -0.870642 -0.664198  1.651735 -0.814982
# 9  0.888957 -1.804149 -1.338037 -1.223141

# %%
ax = df.plot(kind='bar')
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
# Customize our plot with set method
ax = df.plot(kind='bar')
ax.set(title="Random bar graph from DataFrame", xlabel="Row Number", ylabel="Random Number")
ax.legend().set_visible(True)

# %%
# Set the style
plt.style.use('seaborn-whitegrid')

## OO method from scratch
fig, ax = plt.subplots(figsize=(10,6))

## Plot the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"],
                    cmap="cividis");
# Customize the plot
ax.set(title="Heart Disease and Cholestrol Levels",
      xlabel="Age",
      ylabel="Cholestrol");
# Add a legend
ax.legend(*scatter.legend_elements(), title="Target");

# Add a horizontal line
ax.axhline(over_50["chol"].mean(), linestyle='--');

# %%
# Customizing the y and x axis limitations


# Subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10));
#Add data to ax0
scatter = ax0.scatter(x=over_50["age"], y=over_50["chol"], c=over_50["target"], cmap="winter");

#Customizw ax0
ax0.set(title="Heart Disease and Cholestrol Levels",
       xlabel="Age",
       ylabel="Cholestrol");
# CHange the x axis limits
ax0.set_xlim([50, 80])

# Add a legend
ax0.legend(*scatter.legend_elements(), title="Target");

#Add a meanline
ax0.axhline(y=over_50["chol"].mean(), linestyle='--');

# Add a data to ax1
scatter = ax1.scatter(x=over_50["age"],
                      y=over_50["thalach"],
                      c=over_50["target"],
                     cmap="plasma");

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate",
       xlabel="Age",
       ylabel="Max Heart Rate");
# change ax1 x axis limits
ax1.set_xlim([50, 80])
ax1.set_ylim([60, 200])

# Add a legend to ax1

ax1.legend(*scatter.legend_elements(), title="Target");

# Add a meanline
ax1.axhline(y=over_50["thalach"].mean(), linestyle='--');

# Add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");
